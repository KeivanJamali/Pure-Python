# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import numpy as np
from reformat_data import *
from clean_data import Data_Loader

# %%
data_people = people_reformat(r"/mnt/Data1/Python_Projects/Pure-Python/P5/01-Thesis/data/Shiraze94_fa/People.xlsx")
data_family = family_reformat(r"/mnt/Data1/Python_Projects/Pure-Python/P5/01-Thesis/data/Shiraze94_fa/Family.xlsx")
data_trips = trips_reformat(r"/mnt/Data1/Python_Projects/Pure-Python/P5/01-Thesis/data/Shiraze94_fa/Trips.xlsx")

# %%
dataloader = Data_Loader(data_list=[data_people, data_family, data_trips])

# %%
dataloader.set_setting()

# %%
dataloader.raw_data
# Out:
#        trip_code  questionnaire_code  person_number  origin_area_code  \
# 0         120670            11010014              1               252
# 1         120671            11010014              1               128
# 2         100368            11010080              1               171
# 3         100370            11010080              1               170
# 4         100371            11010080              1               171
# ...          ...                 ...            ...               ...
# 93936     107679            32318109              1                30
# 93937     107672            32318110              1                27
# 93938     107673            32318110              1                30
# 93939     107674            32318110              1                27
# 93940     107675            32318110              1                30
#
#        origin_region_code  destination_area_code  destination_region_code  \
# ...

# %%
data_family
# Out:
#        questionnaire_code  family_members_count  total_vehicles_count  \
# 0                11010014                     6                     0
# 1                11010080                     5                     1
# 2                11010117                     3                     1
# 3                11010152                     4                     2
# 4                11010157                     4                     2
# ...                   ...                   ...                   ...
# 18639            32318106                     1                     1
# 18640            32318107                     1                     1
# 18641            32318108                     1                     0
# 18642            32318109                     1                     1
# 18643            32318110                     1                     1
#
#        bicycles_24inch_or_larger_count  motorcycles_count  private_cars_count  \
# ...

# %%
important_data_people = ["age", "gender", "job", "working", "driving_license", "education_level", "home_area_code", "home_region_code"]
important_data_family = ["family_members_count", "total_vehicles_count", "correction_factor", "home_area_code", "home_region_code"]
important_data_trips = ["origin_area_code", "origin_region_code", "destination_area_code", "destination_region_code", "trip_purpose", "travel_mode", "start_hour", "start_minute", "trip_distance", "home_based"]
