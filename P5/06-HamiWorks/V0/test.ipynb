# %%
# %load_ext autoreload
# %autoreload 2

# %%
from data_analysis import Pre_Analysis, Post_Analysis
from match_people import store_matching_file
from pathlib import Path
from data_visulazation import Visulaze

output_folder = Path(r"/mnt/Data1/Python_Projects/Pure-Python/P5/06-HamiWorks/output")
input_folder  = Path(r"/mnt/Data1/Python_Projects/Pure-Python/P5/06-HamiWorks/input")
plot_folder = Path(r"/mnt/Data1/Python_Projects/Pure-Python/P5/06-HamiWorks/plots")

# %%
show = Visulaze(output_path=output_folder, plot_path=plot_folder)
# show.analyze_conversation(True, True, True, True, True)
show.analyze_students()
# Out:
# 6675 6675
# /mnt/Data1/Python_Projects/Pure-Python/P5/06-HamiWorks/V0/data_visulazation.py:87: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat((pd.read_csv(f) for f in all_files), ignore_index=True)

# %%
show.df
# Out:
#             file_name                                            subject  \
# 0     file_16_656.txt                            برگزاری امتحانات عمومی
# 1      file_7_264.txt                    میخواهم پروپوزال رو ویرایش کنم
# 2     file_16_258.txt              درخواست شرکت در امتحانات تابستان ۱۴۰۴
# 3     file_16_261.txt  درخواست شرکت در امتحانات تابستان ۱۴۰۴ ( امتحان...
# 4     file_16_737.txt                      درخواست امتحان مجدد در شهریور
# ...               ...                                                ...
# 6670   file_11_45.txt              درخواست شرکت در امتحانات تابستان ۱۴۰۴
# 6671    file_7_78.txt     درخواست کد اخلاق برای دانشجویان پزشکی  پرستاری
# 6672   file_7_223.txt  درخواست ویرایش اطلاعات دانشجویی(شامل : تغییر ش...
# 6673   file_7_105.txt              درخواست شرکت در امتحانات تابستان 1404
# 6674  file_15_118.txt                             درخواست تعویق امتحانات
#
#       refrence_code            student_name   national_id        student_id  \
# 0      4.421350e+15            Elnaz Karami  4421350443.0  40210510401016.0
# 1      1.990935e+15       Mehran Khayatpour    1990935109       10539802667
# 2      4.040407e+15          Negin Mahmoudi  4040406850.0  40110510810022.0
# 3      4.040407e+15          Negin Mahmoudi  4040406850.0  40110510810022.0
# 4      4.040407e+15          Negin Mahmoudi  4040406850.0  40110510810022.0
# ...             ...                     ...           ...               ...
# 6670   4.421254e+15  yeganeh lazemisakhvidi  4421253820.0  40110520735033.0
# 6671   1.130548e+15   امیرحسین زهتاب خوزانی    1130548155       10539802732
# 6672   1.130548e+15   امیرحسین زهتاب خوزانی    1130548155       10539802732
# 6673   3.300311e+15    محمدپارسا مسعودی راد    3300310970         403591507
# 6674   2.051296e+15      فرزانه قبادی فومشی  2051295603.0       403555258.0
#
#                                       major  \
# 0          کارشناسی پیوسته_پرستاری_یزد_4021
# 1                دکتری عمومی_پزشکی_یزد_3981
# 2           کارشناسی پیوسته_هوشبری_یزد_4011
# 3           کارشناسی پیوسته_هوشبری_یزد_4011
# 4           کارشناسی پیوسته_هوشبری_یزد_4011
# ...                                     ...
# 6670    کارشناسی پیوسته_روان شناسی_یزد_4011
# 6671             دکتری عمومی_پزشکی_یزد_3981
# 6672             دکتری عمومی_پزشکی_یزد_3981
# 6673             دکتری عمومی_پزشکی_یزد_4031
# 6674  کارشناسی پیوسته_میکروبیولوژی_یزد_4031
#
#                                                 message           latency  \
# 0     {('request_details', jdatetime.datetime(1404, ...   1 days 07:05:26
# 1     {('request_details', jdatetime.datetime(1404, ...   1 days 01:12:48
# 2     {('request_details', jdatetime.datetime(1404, ...  10 days 22:12:05
# 3     {('request_details', jdatetime.datetime(1404, ...  10 days 21:54:52
# 4     {('request_details', jdatetime.datetime(1404, ...   0 days 06:20:31
# ...                                                 ...               ...
# 6670  {('request_details', jdatetime.datetime(1404, ...   0 days 09:59:18
# 6671  {('request_details', jdatetime.datetime(1404, ...   0 days 01:51:18
# 6672  {('request_details', jdatetime.datetime(1404, ...   0 days 00:18:14
# 6673  {('request_details', jdatetime.datetime(1404, ...   0 days 04:46:47
# 6674  {('request_details', jdatetime.datetime(1404, ...   1 days 07:23:58
#
#               duration  ... reference_id  id name refrence_id  total_messages  \
# 0      1 days 07:05:26  ...          NaN NaN  NaN         NaN             NaN
# 1      1 days 03:16:31  ...          NaN NaN  NaN         NaN             NaN
# 2     10 days 22:12:05  ...          NaN NaN  NaN         NaN             NaN
# 3     10 days 21:54:52  ...          NaN NaN  NaN         NaN             NaN
# 4      0 days 06:20:31  ...          NaN NaN  NaN         NaN             NaN
# ...                ...  ...          ...  ..  ...         ...             ...
# 6670   0 days 09:59:18  ...          NaN NaN  NaN         NaN             NaN
# 6671   2 days 01:26:50  ...          NaN NaN  NaN         NaN             NaN
# 6672   5 days 01:07:59  ...          NaN NaN  NaN         NaN             NaN
# 6673   0 days 04:50:13  ...          NaN NaN  NaN         NaN             NaN
# 6674   1 days 07:23:58  ...          NaN NaN  NaN         NaN             NaN
#
#      null_mean delay_mean  duration_mean  delay_mean_hours duration_mean_hours
# 0          NaN        NaN            NaN               NaN                 NaN
# 1          NaN        NaN            NaN               NaN                 NaN
# 2          NaN        NaN            NaN               NaN                 NaN
# 3          NaN        NaN            NaN               NaN                 NaN
# 4          NaN        NaN            NaN               NaN                 NaN
# ...        ...        ...            ...               ...                 ...
# 6670       NaN        NaN            NaN               NaN                 NaN
# 6671       NaN        NaN            NaN               NaN                 NaN
# 6672       NaN        NaN            NaN               NaN                 NaN
# 6673       NaN        NaN            NaN               NaN                 NaN
# 6674       NaN        NaN            NaN               NaN                 NaN
#
# [6675 rows x 23 columns]

# %%
obj = Post_Analysis(output_path=output_folder)

# %%
obj.hami_data[105001]
# Out:
#         file_name                                            subject  \
# 0    file_1_1.txt                          گواهی موقت پایان تحصیلات
# 1    file_1_2.txt                             درخواست معادلسازی دروس
# 2    file_1_3.txt                     درخواست گواهی اشتغال  به تحصیل
# 3    file_1_4.txt                     درخواست گواهی اشتغال  به تحصیل
# 4    file_1_5.txt                    از من بپرس (اخذ راهنمایی اداری)
# 5    file_1_6.txt                     درخواست گواهی اشتغال  به تحصیل
# 6    file_1_7.txt                           درخواست تاسیس انجمن علمی
# 7    file_1_8.txt                    درخواست فعالسازی ایمیل دانشجویی
# 8    file_1_9.txt       درخواست تغییر رمز و مشکل در ورود به آموزشیار
# 9   file_1_10.txt                         درخواست صدور کارت دانشجویی
# 10  file_1_11.txt       درخواست تغییر رمز و مشکل در ورود به آموزشیار
# 11  file_1_12.txt                         درخواست صدور کارت دانشجویی
# 12  file_1_13.txt                درخواست تخفیف شهریه ( چند دانشجویی)
# 13  file_1_14.txt                             درخواست فعالسازی ایمیل
# 14  file_1_15.txt                                              ایمیل
# 15  file_1_16.txt                درخواست تخفیف شهریه ( چند دانشجویی)
# 16  file_1_17.txt                                       ترم تابستانه
# 17  file_1_18.txt                              درخواست کارت دانشجوی
# 18  file_1_19.txt                          درخواست فعالسازی رمز عبور
# 19  file_1_20.txt  درخواست شرکت در آزمون های پایان ترم دوم 1403 ب...
# 20  file_1_21.txt                          درخواست فعالسازی رمز عبور
# 21  file_1_22.txt  با سلام و احترام اینجانب سجاد چنانی به شماره د...
# 22  file_1_23.txt  به علت مسافرت به پایتخت ایران ودرگیری درتهران ...
# 23  file_1_24.txt                                برگذاری امتحان مجدد
# 24  file_1_25.txt                     درخواست برگزاری مجدد امتحانات
# 25  file_1_26.txt                   اولین درخواست برای ثبت در سامانه
# 26  file_1_27.txt  درخاست امتحان مجدد درس کارگاه انتقال قدرت خودر...
# 27  file_1_28.txt                        رفع مشکلات احتمالی آموزشیار
# 28  file_1_29.txt                                درخواست امتحان مجدد
# 29  file_1_30.txt                               تست درخواست دانشجویی
# 30  file_1_31.txt                                        امتحان مجدد
# 31  file_1_32.txt                                        امتحان مجدد
# 32  file_1_33.txt                                        امتحان مجدد
# 33  file_1_34.txt                                        امتحان مجدد
# 34  file_1_35.txt                                 درخواست ازمون مجدد
# 35  file_1_36.txt                                    ایمیل دانشجویی
# 36  file_1_37.txt                         درخواست فعالسازی رمز عبور
# 37  file_1_38.txt                         درخواست فعالسازی رمز عبور
# 38  file_1_39.txt                         درخواست فعالسازی رمز عبور
# 39  file_1_40.txt                           درخواست برای ترم تابستان
# 40  file_1_41.txt                                                NaN
# 41  file_1_42.txt                     سلام امتحانات از کی شروع میشه؟
# 42  file_1_43.txt                         درخواست صدور کارت دانشجویی
# 43  file_1_44.txt                                                NaN
# 44  file_1_45.txt                  سلام تاریخ شروع امتحانات کی است ؟
#
#        refrence_code                 student_name   national_id    student_id  \
# 0   6820037252902249                    Laya Kord  6.820037e+09  4.021056e+13
# 1    445008375112150             zahrhra morkiana  4.450084e+09           NaN
# 2   5610029325940503                  فاطمه رضایی  5.610029e+09           NaN
# 3    445008375160221             zahrhra morkiana  4.450084e+09           NaN
# 4   4421090451466334      حمیدرضا حلاجی نوقی زاده  4.421090e+09           NaN
# 5    445008375186415             zahrhra morkiana  4.450084e+09  4.021054e+13
# 6   4421208256402392             Marzieh Jabinian  4.421208e+09  4.021056e+13
# 7   4450036662278281          مرضیه زارع عبداللهی  4.450037e+09  4.032041e+08
# 8   2480636224217741                yeganeh lotfi  2.480636e+09  4.037356e+08
# 9   4450036662316459          مرضیه زارع عبداللهی  4.450037e+09  4.032041e+08
# 10  4420255609574552                 neda dehghan  4.420256e+09  4.032050e+08
# 11  4433394424321278                مژگان عابدینی  4.433394e+09  4.031653e+08
# 12  3950015302356892                     پریا سیف  3.950015e+09  4.031031e+08
# 9                    کاردانی پیوسته_حسابداری_یزد_4031
# 10                   کاردانی پیوسته_حسابداری_یزد_4031
# 11                کارشناسی ناپیوسته_حسابداری_یزد_4031
# 12                کارشناسی ناپیوسته_حسابداری_یزد_4021
# 13                کارشناسی ناپیوسته_حسابداری_یزد_4031
# 14                کارشناسی ناپیوسته_حسابداری_یزد_4031
# 15        کارشناسی ناپیوسته_حقوق - حقوق ثبتی_یزد_4021
# 16        کارشناسی ناپیوسته_حقوق - حقوق ثبتی_یزد_4021
# 17   کارشناسی ناپیوسته_آموزش و پرورش ابتدایی_یزد_4032
# 18                کارشناسی ناپیوسته_حسابداری_یزد_4031
# 19  کاردانی ناپیوسته_کاردانی فنی ایمنی کار و حفاظت...
# 20                کارشناسی ناپیوسته_حسابداری_یزد_4031
# 21        کارشناسی ناپیوسته_حقوق - حقوق ثبتی_یزد_4021
# 22               کاردانی پیوسته_مکانیک خودرو_یزد_4021
# 23   کارشناسی ناپیوسته_مهندسی حرفه ای معماری_یزد_4021
# 24   کارشناسی ناپیوسته_مهندسی حرفه ای معماری_یزد_4021
# 25               کاردانی پیوسته_مکانیک خودرو_یزد_4021
# 26               کاردانی پیوسته_مکانیک خودرو_یزد_4021
# 27                                                NaN
# 28   کارشناسی ناپیوسته_مهندسی حرفه ای معماری_یزد_4021
# 29  کارشناسی ناپیوسته_مهندسی حرفه ای برق قدرت_یزد_...
# 30  کارشناسی ناپیوسته_مهندسی حرفه ای مواد ریخته گر...
# 31  کارشناسی ناپیوسته_مهندسی حرفه ای مواد ریخته گر...
# 32  کارشناسی ناپیوسته_مهندسی حرفه ای مواد ریخته گر...
# 33  کارشناسی ناپیوسته_مهندسی حرفه ای مواد ریخته گر...
# 34  کارشناسی ناپیوسته_مهندسی حرفه ای صنایع نساجی_ی...
# 35                کارشناسی ناپیوسته_حسابداری_یزد_4031
# 36                کارشناسی ناپیوسته_حسابداری_یزد_4031
# 37                کارشناسی ناپیوسته_حسابداری_یزد_4031
# 38                کارشناسی ناپیوسته_حسابداری_یزد_4031
# 39  کاردانی ناپیوسته_کاردانی حرفه ای حقوق- حقوق ثب...
# 40                                                NaN
# 41  کارشناسی ناپیوسته_مهندسی حرفه ای کامپیوتر نرم ...
# 42                کارشناسی ناپیوسته_حسابداری_یزد_4031
# 43                                                NaN
# 44  کارشناسی ناپیوسته_مهندسی حرفه ای کامپیوتر نرم ...
#
#                                               message            latency  \
# 0                                                 NaN    7 days 19:32:15
# 1   "با سلام،\nبه اطلاع می‌رساند با توجه به تعطیلا...    1 days 01:57:29
# 2   "با سلام،\nبه اطلاع می‌رساند با توجه به تعطیلا...    0 days 14:05:57
# 3                                                 NaN    1 days 01:58:57
# 4   سلام شروع امتحانات چه زمانی هست؟\nسلام و عرض ا...    2 days 05:28:00
# 5                                                 NaN    3 days 21:45:47
# 6                                                 NaN    7 days 23:29:55
# 7                                                 NaN    2 days 22:52:20
# 8                                                 NaN    2 days 23:06:36
# 9                                                 NaN    2 days 22:46:20
# 10                                                NaN    2 days 23:17:05
