# %%
class Car:
    def __init__(self, name: str,  model: str, year: int, speed: float, price: float):
        self.name = name
        self.model = model
        self.year = year
        self.speed = speed
        self.price = price
        self.if_you_are_at_traffic_light = False
        self.mode = None

    def offer(self, o: int) -> float:
        return self.price * (1 - o/100)
    
    def change_mode(self):
        self.if_you_are_at_traffic_light = True if not self.if_you_are_at_traffic_light else False

# %%
import random

names = ["ali", "hamed", "mohammad", "reza", "keivan", "a"]
speeds = [random.random()*100 for i in range(10)]
years = [int("13"+str(i)) for i in range(70, 100)]
princes = [1000, 1200, 1400, 1600, 1800]

cars = []
for i in range(5):
    print(i)
    cars.append(Car(name=names[i], model="pride", year=years[i],
                    speed=speeds[i], price=princes[i]))
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
cars[0].offer(.0001)
# Out:
# 999.999

# %%
cars[3].offer(7)
# Out:
# 1488.0

# %%
class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y
        
    def __add__(self, a):
        self.x = self.x + a.x
        self.y = self.y + a.y
        
    def __str__(self):
        return f"x={self.x} and y={self.y}"
    
    def __repr__(self):
        return f"x={self.x} and y={self.y}"

# %%
point1 = Point(x=20, y=20)
point2 = Point(x=5, y=7)
point1 + point2

# %%
print(point1)
point1
# Out:
# x=25 and y=27
# x=25 and y=27

# %%
a[0] + a[-1]

# %%
a[0].x
# Out:
# 49

# %%
point1.y
# Out:
# 30

# %%
class Animals:
    def __init__(self, name, weight, type, age):
        self.name = name
        self.weight = weight
        self.type = type
        self.age = age

    def talk(self):
        if self.type == "cat":
            print("Mio")
        elif self.type == "roster":
            print("GhoGhoLiGhoGho")
        else:
            print("go die")

# %%
animal1 = Animals("lion", 50, "cat", 30)
animal2 = Animals("aran", 50, "roster", 30)
animal3 = Animals("zohre", 50, "goghd", 30)

# %%
a = [animal1, animal2, animal3]

for i in range(len(a)):
    a[i].talk()
# Out:
# Mio
# GhoGhoLiGhoGho
# go die

# %%
len(a)
# Out:
# 3

# %%
animal2.talk()
# Out:
# GhoGhoLiGhoGho

# %%
animal3.talk()
# Out:
# go die
