# %%
# %load_ext autoreload
# %autoreload 2

# %%
from dataloader import Dataloader_Distance
path_e = r"/mnt/Data1/Python_Projects/Pure-Python/P5/09-FaragitiWorks/p2-pickSomeData/data/Input_File.XLS"
data = Dataloader_Distance(path_e)

# %%
data.fit("L2:R1")
# Out:
#        Distance  Offset  Elevation
# 0      1300.000    -3.6   1428.716
# 1      1300.000     0.0   1428.788
# 2      1300.000     0.0   1428.788
# 3      1320.000    -3.6   1428.597
# 4      1320.000     0.0   1428.669
# ...         ...     ...        ...
# 3970  21540.000    -0.5   1343.788
# 3971  21540.000    -0.5   1343.788
# 3972  21559.423   -10.7   1344.396
# 3973  21559.423    -0.5   1344.600
# 3974  21559.423    -0.5   1344.600
#
# [3975 rows x 3 columns]

# %%
data.data
# Out:
#        No.  Name   Distance        PL        GL  NaN        L5        L4  \
# 0        1    27       1300  1428.788   1428.25  NaN       6.9       6.3
# 1      NaN   NaN        NaN       NaN       NaN  NaN  1428.098  1428.098
# 2        2    28       1320  1428.669  1428.122  NaN       6.9       6.3
# 3      NaN   NaN        NaN       NaN       NaN  NaN  1427.979  1427.979
# 4        3    29       1340  1428.488  1428.031  NaN       6.9       6.3
# ...    ...   ...        ...       ...       ...  ...       ...       ...
# 2645   NaN   NaN        NaN       NaN       NaN  NaN       NaN  1339.616
# 2646  1324  1334      21540  1343.788  1340.682  NaN       NaN     21.73
# 2647   NaN   NaN        NaN       NaN       NaN  NaN       NaN  1340.349
# 2648  1325  1335  21559.423    1344.6  1341.837  NaN       NaN     20.96
# 2649   NaN   NaN        NaN       NaN       NaN  NaN       NaN  1341.419
#
#             L3        L2        L1        R1        R2        R3        R4  \
# ...
