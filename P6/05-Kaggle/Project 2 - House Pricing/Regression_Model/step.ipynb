# %%
# %load_ext autoreload
# %autoreload 2

# %%
from DataLoader_old import Dataloader
from Engine import Engine
import Information_old as info
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# %%
data_path = Path(r"D:\All Python\Kaggle\data\house_prices\train.csv")
dataloader = Dataloader(data_path=data_path, seed=42)
dataloader.data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7004\233640029.py in ?()
#       1 data_path = Path(r"D:\All Python\Kaggle\data\house_prices\train.csv")
# ----> 2 dataloader = Dataloader(data_path=data_path, seed=42)
#       3 # dataloader.data
#
# d:\All Python\Kaggle\Project 2 - House Pricing\Regression_model\DataLoader_old.py in ?(self, data_path, seed)
#      11         self.seed = seed
#      12         self.raw_data = pd.read_csv(data_path, index_col=0)
#      13         self.data = self.raw_data.copy()
#      14         self.set_setting()
# ---> 15         self._scale_data()
#
# d:\All Python\Kaggle\Project 2 - House Pricing\Regression_model\DataLoader_old.py in ?(self)
#      22     def _scale_data(self):
#      23         self.scaler = MinMaxScaler()
# ...

# %%
model = Engine(data=dataloader.data)
model.fit()

# %%
sum(model.model.params < 0.1)

# %%
model.weight_plot(cons=False, alpha=0.05)

# %%
model.effect_plot(data_id=5)

# %%
model.data
