# %%
# %load_ext autoreload
# %autoreload 2

# %%
import networkx as nx
import osmnx as ox
import matplotlib.pyplot as plt
from modular.DataLoader import Data_loader
from modular.Engine import Engine
# Out:
# d:\All Python\Pure-Python\P4\08-System\Projectterm\modular\Engine.py:189: SyntaxWarning: invalid escape sequence '\l'
#   var_name = "\lambda_" + "{" + f"{o}-{d}" + "}"

# %%
city = "Yazd, Yazd, Iran"
data = Data_loader(city_name=city)
data.get_data(file_name="Yazd")
data.set_setting(number_of_nodes=20)
# Out:
# [INFO] Data is loaded from the local device.
# [INFO] -> Undirected
# [INFO] Largest component founded!
# [INFO] Found a connected subgraph with 20 nodes and 23 edges.
#
# [INFO] Node Labels:
# OSM ID: 3684753768, Label: 1
# OSM ID: 3684773634, Label: 2
# OSM ID: 3684773636, Label: 3
# OSM ID: 3684773637, Label: 4
# OSM ID: 3684773639, Label: 5
# OSM ID: 3684773642, Label: 6
# OSM ID: 3684773645, Label: 7
# OSM ID: 3684773646, Label: 8
# OSM ID: 3684773648, Label: 9
# OSM ID: 3684773649, Label: 10
# OSM ID: 3684773650, Label: 11
# OSM ID: 3684773651, Label: 12
# OSM ID: 3684773652, Label: 13
# OSM ID: 3684773653, Label: 14
# OSM ID: 3686154378, Label: 15
# OSM ID: 7007158526, Label: 16
# OSM ID: 7462458602, Label: 17
# OSM ID: 9767942008, Label: 18
# OSM ID: 9768034269, Label: 19
# OSM ID: 9768034270, Label: 20
#
# [INFO] Edge Indices (based on node label sums):
# Edge (2, 3): Index = 1
# Edge (3, 4): Index = 2
# Edge (6, 7): Index = 3
# Edge (5, 9): Index = 4
# Edge (7, 8): Index = 5
# Edge (5, 11): Index = 6
# Edge (1, 16): Index = 7
# Edge (6, 13): Index = 8
# Edge (8, 11): Index = 9
# Edge (9, 10): Index = 10
# Edge (3, 17): Index = 11
# Edge (5, 15): Index = 12
# Edge (3, 18): Index = 13
# Edge (6, 15): Index = 14
# Edge (9, 13): Index = 15
# Edge (11, 12): Index = 16
# Edge (6, 18): Index = 17
# Edge (7, 20): Index = 18
# Edge (13, 14): Index = 19
# Edge (8, 20): Index = 20
# Edge (15, 13): Index = 21
# Edge (18, 16): Index = 22
# Edge (19, 20): Index = 23

# %%
data.plot_graph(data.graph, original=False, seed=5)

# %%
model = Engine(graph=data.graph,
               student_number="403209743")
model.set_setting(origins=[1, 2, 10], destinations=[6])
model.kuhn_tucker(method="SO")


# model.set_setting(origins=[10, 8, 19], destinations=[2])
# model.set_setting(origins=[4, 7], destinations=[5])
# Out:
# [INFO] In this scenario we have 10 possable path.
# [INFO] Start solving the lagrange problem... Iteration 0
# [INFO] We need 1 times of solving system of equations to finish this step.
#   0%|          | 0/1 [00:00<?, ?it/s]
# [INFO] Start solving the lagrange problem... Iteration 1
# [INFO] We need 10 times of solving system of equations to finish this step.
#   0%|          | 0/10 [00:00<?, ?it/s]
# [INFO] Start solving the lagrange problem... Iteration 2
# [INFO] We need 45 times of solving system of equations to finish this step.
#   0%|          | 0/45 [00:00<?, ?it/s]
# [INFO] Start solving the lagrange problem... Iteration 3
# [INFO] We need 120 times of solving system of equations to finish this step.
#   0%|          | 0/120 [00:00<?, ?it/s]
# [INFO] The value of objective function is : 9534.2
# [success] Finished calculations!
# [INFO] At iteration 3 with setting (f_{10-6}^0, f_{10-6}^4, f_{10-6}^6) to zero, we get objective function equal to 9534.2
# [INFO] The value of objective function is : 9805.1
# [success] Finished calculations!
# [INFO] At iteration 3 with setting (f_{10-6}^2, f_{10-6}^4, f_{10-6}^7) to zero, we get objective function equal to 9805.1
# [INFO] The value of objective function is : 9360.6
# [success] Finished calculations!
# [INFO] At iteration 3 with setting (f_{10-6}^2, f_{10-6}^5, f_{10-6}^6) to zero, we get objective function equal to 9360.6
# [INFO] The value of objective function is : 9514.8
# [success] Finished calculations!
# [INFO] At iteration 3 with setting (f_{10-6}^4, f_{10-6}^5, f_{10-6}^6) to zero, we get objective function equal to 9514.8
# [INFO] The value of objective function is : 9360.62
# [success] Finished calculations!
# [Result] x_{2-3} => x=16.0  --  t=194.0
# [Result] x_{3-18} => x=16.0  --  t=165.0
# [Result] x_{3-17} => x=0.0  --  t=11.0
# [Result] x_{3-4} => x=0.0  --  t=14.0
# [Result] x_{5-11} => x=1.1  --  t=15.8
# [Result] x_{5-9} => x=1.2  --  t=34.3
# [Result] x_{5-15} => x=0.1  --  t=9.1
# [Result] x_{6-18} => x=19.0  --  t=125.0
# [Result] x_{6-15} => x=1.0  --  t=21.5
# [Result] x_{6-13} => x=2.9  --  t=44.7
# [Result] x_{6-7} => x=1.1  --  t=15.8
# [Result] x_{15-13} => x=1.1  --  t=25.2
# [Result] x_{7-20} => x=0.1  --  t=19.7
# [Result] x_{7-8} => x=1.0  --  t=22.8
# [Result] x_{8-20} => x=0.1  --  t=14.1
# [Result] x_{8-11} => x=1.1  --  t=26.6
# [Result] x_{9-10} => x=5.0  --  t=89.0
# [Result] x_{9-13} => x=3.8  --  t=55.2
# [Result] x_{11-12} => x=0.0  --  t=1.0
# [Result] x_{13-14} => x=0.0  --  t=11.0
# [Result] x_{19-20} => x=0.0  --  t=10.0
# [Result] x_{1-16} => x=3.0  --  t=49.0
# [Result] x_{18-16} => x=3.0  --  t=43.0

# %%
model.get_path_travel_time()
# Out:
# [Result] For flow f_{1-6}^0 which has the following path, we have a total travel time of 217.000000000000
# [Continue] [1, 16, 18, 6]
# [Result] For flow f_{2-6}^0 which has the following path, we have a total travel time of 484.000000000000
# [Continue] [2, 3, 18, 6]
# [Result] For flow f_{10-6}^0 which has the following path, we have a total travel time of 204.408420437732
# [Continue] [10, 9, 5, 11, 8, 7, 6]
# [Result] For flow f_{10-6}^1 which has the following path, we have a total travel time of 215.408420437732
# [Continue] [10, 9, 5, 11, 8, 20, 7, 6]
# [Result] We assume 0 for flow f_{10-6}^2 which has the following path.
# [Continue] [10, 9, 5, 15, 6]
# [Result] For flow f_{10-6}^3 which has the following path, we have a total travel time of 202.408420437732
# [Continue] [10, 9, 5, 15, 13, 6]
# [Result] For flow f_{10-6}^4 which has the following path, we have a total travel time of 188.908420437732
# [Continue] [10, 9, 13, 6]
# [Result] We assume 0 for flow f_{10-6}^5 which has the following path.
# [Continue] [10, 9, 13, 15, 5, 11, 8, 7, 6]
# [Result] We assume 0 for flow f_{10-6}^6 which has the following path.
# [Continue] [10, 9, 13, 15, 5, 11, 8, 20, 7, 6]
# [Result] For flow f_{10-6}^7 which has the following path, we have a total travel time of 190.908420437732
# [Continue] [10, 9, 13, 15, 6]

# %%
model.get_link_flows_travel_time(model.solution)
# Out:
# [Result] x_{2-3} => x=16.0  --  t=194.0
# [Result] x_{3-18} => x=16.0  --  t=165.0
# [Result] x_{3-17} => x=0.0  --  t=11.0
# [Result] x_{3-4} => x=0.0  --  t=14.0
# [Result] x_{5-11} => x=1.1  --  t=15.8
# [Result] x_{5-9} => x=1.2  --  t=34.3
# [Result] x_{5-15} => x=0.1  --  t=9.1
# [Result] x_{6-18} => x=19.0  --  t=125.0
# [Result] x_{6-15} => x=1.0  --  t=21.5
# [Result] x_{6-13} => x=2.9  --  t=44.7
# [Result] x_{6-7} => x=1.1  --  t=15.8
# [Result] x_{15-13} => x=1.1  --  t=25.2
# [Result] x_{7-20} => x=0.1  --  t=19.7
# [Result] x_{7-8} => x=1.0  --  t=22.8
# [Result] x_{8-20} => x=0.1  --  t=14.1
# [Result] x_{8-11} => x=1.1  --  t=26.6
# [Result] x_{9-10} => x=5.0  --  t=89.0
# [Result] x_{9-13} => x=3.8  --  t=55.2
# [Result] x_{11-12} => x=0.0  --  t=1.0
# [Result] x_{13-14} => x=0.0  --  t=11.0
# [Result] x_{19-20} => x=0.0  --  t=10.0
# [Result] x_{1-16} => x=3.0  --  t=49.0
# [Result] x_{18-16} => x=3.0  --  t=43.0

# %%
sum(model.graph.edges[1, 9]["flows"])
# Out:
# 0

# %%
model.graph.edges[6, 12]["travel_time"] + model.graph.edges[12, 16]["travel_time"] + model.graph.edges[16, 15]["travel_time"]
# Out:
# 6*x_{12-16} + 1.75*x_{12-6} + 19*x_{15-16} + 22.25

# %%
model.graph.nodes[10]["production"]
# Out:
# 5

# %%
import math
x = 3.687
l = 0.5
x - 6 * ((math.exp(-l*(3+x-3)))/(math.exp(-l*(3+x-3)) + math.exp(-l*(12-2*x))))
# Out:
# -0.004592437628560209

# %%
1/4.34
# Out:
# 0.2304147465437788
