# %%
import matplotlib.pyplot as plt
import numpy as np
import sympy as sp

# %%
sp.Derivative

# %%
p, q = sp.symbols("p, q")
p_func = 2.5*(3+(24000)/(7200-q))
# q_func = 7200 - (60000/(p-7.5))
p_func_der = sp.Derivative(p_func)
marginal_cost = p_func_der.doit()

average_cost = 3.8*10**4/q

sp.solve(marginal_cost-average_cost, q)
# Out:
# [7094.16375295356, 7307.41519441486]

# %%
2.5*(3+(200/(-1*(7094/120-60))))
# Out:
# 573.5377358490568

# %%
x_values = np.linspace(0, 7, 80)
lambdify1 = sp.lambdify("p", q_func, "numpy")
y_values = lambdify1(x_values)

plt.plot(x_values, y_values)

x_values = np.linspace(0, 20, 800)
lambdify1 = sp.lambdify("p", D_func, "numpy")
y_values = lambdify1(x_values)

plt.plot(x_values, y_values)
# Out:
# <lambdifygenerated-23>:2: RuntimeWarning: divide by zero encountered in divide
#   return 38000.0/p

# %%
x_values = np.linspace(0, 800, 800)
lambdify1 = sp.lambdify("p", D_func, "numpy")
y_values = lambdify1(x_values)

plt.plot(x_values, y_values)
# Out:
# <lambdifygenerated-11>:2: RuntimeWarning: divide by zero encountered in divide
#   return 38000.0/p
