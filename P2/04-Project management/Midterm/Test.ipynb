# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt

# %%
import toolkit as tl

tl.plotting("test", tl.u, 2)

# %%
initial_wealth = 10000
gain = 5000
loss = 3500
p_gain = 0.5
p_loss = 0.5

print("expected value", tl.expected_value(gain=[5000, -3500], probability=[0.5, 0.5]))
print("expected utility", tl.expected_utility(gain=[5000, -3500], probability=[0.5, 0.5], wealth=10000))
print(tl.u2(10000))
print(tl.u2(15000))
print(tl.u2(6500))

def line(x):
    return ((tl.u2(15000)-tl.u2(6500))/(15000-6500))*(x-6500)+tl.u2(6500)

print(10**tl.expected_utility(gain=[5000, -3500], probability=[0.5, 0.5], wealth=10000), "certainty equivalent")
# Out:
# expected value 750.0
# expected utility 3.9945023078492685
# 4.0
# 4.176091259055681
# 3.8129133566428557
# 9874.208829065752 certainty equivalent
