# %%
# %load_ext autoreload
# %autoreload 2
from Generic_DataLoader_V3 import Generic_DataLoader
from PPK_Processing import PPK_Processing_Result_DataLoader
from CSDP_DataLoader import CSDP_DataLoader
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
file_name = r'C:\Users\keipj\Desktop\Book1.csv'
epsilon = 0.25
round = 0.75

dataloader = Generic_DataLoader(file_name=file_name)
dataloader.fit(epsilon=epsilon, round_lim=round)
# Out:
# d:\All Python\Pure-Python\P3\WebPage-Server\Generic_DataLoader_V3.py:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   center_points["Station"] = center_points["Station"].apply(lambda x: x if round_lim <= x % 10 <= (10-round_lim) else int(round(x/10)*10))

# %%
file_name1 = r'C:\Users\keipj\Desktop\main.csv'
file_name2 = r'C:\Users\keipj\Desktop\second.csv'
file_name3 = r'C:\Users\keipj\Desktop\pashneh.csv'
dataloader = CSDP_DataLoader(file_name1, file_name2, file_name3)
# res = dataloader.fit()
# Out:
# d:\All Python\Pure-Python\P3\WebPage-Server\CSDP_DataLoader.py:75: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   for add in temp_additional:

# %%
dataloader.left_bound
# Out:
# [0.02,
#  1064.85,
#  3.04,
#  1064.28,
#  4.81,
#  1064.48,
#  9.18,
#  1064.343,
#  11.26,
#  1063.682,
#  12.19,
#  1063.52,
#  10.67,
#  1064.29,
#  7.25,
#  1065.819,
#  4.86,
#  1065.888,
#  2.79,
#  1066.63,
#  0.01,
#  1067.03,
#  0.01,
#  1067.79,
#  0.01,
#  1068.75,
#  0.01,
#  1069.49,
#  0.01,
#  1070.4,
#  0.01,
#  1071.18,
#  0.01,
#  1071.328,
#  0.01,
#  1071.94,
#  0.01,
#  1072.84,
#  0.01,
#  1073.16]

# %%
dataloader.additionals
# Out:
#           L3        L4        L5        R3
# 0      0.030     empty     empty    12.210
# 1   1063.589     empty     empty  1063.861
# 2      3.060     empty     empty    11.870
# 3   1062.350     empty     empty  1063.853
# 4      4.830     empty     empty    12.440
# 5   1062.891     empty     empty  1063.716
# 6     11.550     empty     empty    12.040
# 7   1063.553     empty     empty  1063.525
# 8     12.440     empty     empty    12.540
# 9   1063.286     empty     empty  1063.382
# 10    12.880     empty     empty    12.190
# 11  1063.288     empty     empty  1063.927
# 12    10.660     empty     empty    13.070
# 13  1064.291     empty     empty  1063.613
# 14     7.250      7.85      8.13    14.320
# 15  1065.819  1065.819  1066.095  1063.573
# 16     4.860     empty     empty    16.090
# 17  1065.891     empty     empty  1063.591
# 18     2.770     empty     empty    10.590
# 19  1066.634     empty     empty  1065.381
# 20     0.010      0.01      0.08    12.120
# 21  1067.030   1067.03  1067.099  1065.115
# 22     0.010     empty     empty    11.880
# 23  1067.790     empty     empty  1065.885
# 24     0.010     empty     empty    12.550
# 25  1068.750     empty     empty  1066.621
# 26     0.010     empty     empty    12.870
# 27  1069.490     empty     empty  1067.254
# 28     0.010     empty     empty    12.390
# 29  1070.400     empty     empty  1068.326
# 30     0.010     empty     empty    12.080
# 31  1071.180     empty     empty  1069.209
# 32     0.010     empty     empty    11.970
# 33  1071.327     empty     empty  1069.393
# 34     0.010     empty     empty    10.370
# 35  1071.940     empty     empty  1070.150
# 36     0.010     empty     empty     9.180
# 37  1072.840     empty     empty  1070.966
# 38     0.010     empty     empty     9.260
# 39  1073.160     empty     empty  1071.109

# %%
dataloader.fit()
# Out:
# d:\All Python\Pure-Python\P3\WebPage-Server\CSDP_DataLoader.py:168: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   result.fillna("", inplace=True)
# d:\All Python\Pure-Python\P3\WebPage-Server\CSDP_DataLoader.py:169: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   result.replace("empty", "", inplace=True)
#       No Distance        L8        L7  ...        R7        R8        R9  end
# 0    1.0      0.0                      ...     12.21                        0
# 1                                      ...  1063.861                        0
# 2    2.0     20.0                      ...                                  0
# 3                                      ...                                  0
# 4    3.0    31.73                      ...                                  0
# 5                                      ...                                  0
# 6    4.0     40.0                      ...                                  0
# 7                                      ...                                  0
# 8    5.0     60.0                      ...                                  0
# 9                                      ...                                  0
# 10   6.0     80.0                      ...                                  0
# 11                                     ...                                  0
# 12   7.0    100.0                      ...                                  0
# 13                                     ...                                  0
# 14   8.0    120.0      8.13      7.85  ...                                  0
# 15                 1066.095  1065.819  ...                                  0
# 16   9.0   120.19                      ...                                  0
# 17                                     ...                                  0
# 18  10.0    140.0                      ...                                  0
# 19                                     ...                                  0
# 20  11.0   157.75                      ...                                  0
# 21                                     ...                                  0
# 22  12.0    200.0                      ...     11.88                        0
# 23                                     ...  1065.885                        0
# 24  13.0    240.0                      ...     12.55     12.55     12.55    0
# 25                                     ...   1066.62     12.55  1066.621    0
# 26  14.0    280.0                      ...                                  0
# 27                                     ...                                  0
# 28  15.0    320.0                      ...     12.39                        0
# 29                                     ...  1068.326                        0
# 30  16.0    360.0                      ...     12.08                        0
# 31                                     ...  1069.209                        0
# 32  17.0   367.75                      ...     11.52     11.97              0
# 33                                     ...     11.52  1069.393              0
# 34  18.0    400.0                      ...     10.37     10.37              0
# 35                                     ...     10.37   1070.15              0
# 36  19.0    440.0                      ...      9.18                        0
# 37                                     ...  1070.966                        0
# 38  20.0   457.74                      ...                                  0
# 39                                     ...                                  0
#
# [40 rows x 21 columns]
