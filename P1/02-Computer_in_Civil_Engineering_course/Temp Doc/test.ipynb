# %%
# %load_ext autoreload
# %autoreload 2
import test as tp
import numpy as np
import sys

np.set_printoptions(threshold=sys.maxsize)  # to print total matrix

# %% [markdown]
# ## Entering Data

# %%
A =(42.1+47+52.8+59.3+73+82.6+102+129+159+195)/100000  #m^2
E = 200 * 10 ** 9  # Pa
node = []
node.append(tp.Point(11.5, 8.5, "01"))
node.append(tp.Point(11.5, 6, "02"))
node.append(tp.Point(12.75, 3, "03"))
node.append(tp.Point(4.75, 3, "04"))
node.append(tp.Point(6, 6, "05"))
node.append(tp.Point(7, 7, "06"))
node.append(tp.Point(6, 8.5, "07"))
node.append(tp.Point(7.75, 11.5, "08"))
node.append(tp.Point(6, 16, "09"))
node.append(tp.Point(7.75, 17, "10"))
node.append(tp.Point(9.75, 17, "11"))
node.append(tp.Point(11.5, 16, "12"))
node.append(tp.Point(8.75, 13, "13"))
node.append(tp.Point(9.75, 11.5, "14"))
node.append(tp.Point(8.75, 8.5, "15"))
node.append(tp.Point(10.5, 7, "16"))
node.append(tp.Point(0, 0, "17"))
node.append(tp.Point(3, 0, "18"))
node.append(tp.Point(6, 0, "19"))
node.append(tp.Point(11.5, 0, "20"))
node.append(tp.Point(14.5, 0, "21"))
node.append(tp.Point(17.5, 0, "22"))

# %% [markdown]
# # Make Elements

# %%
Element = []
Element.append(tp.Element(node[17-1], node[18-1], A=A, E=E))
Element.append(tp.Element(node[18-1], node[19-1], A=A, E=E))
Element.append(tp.Element(node[4-1], node[18-1], A=A, E=E))
Element.append(tp.Element(node[4-1], node[19-1], A=A, E=E))
Element.append(tp.Element(node[4-1], node[17-1], A=A, E=E))
Element.append(tp.Element(node[7-1], node[17-1], A=A, E=E))
Element.append(tp.Element(node[5-1], node[19-1], A=A, E=E))
Element.append(tp.Element(node[4-1], node[5-1], A=A, E=E))
Element.append(tp.Element(node[4-1], node[7-1], A=A, E=E))
Element.append(tp.Element(node[6-1], node[19-1], A=A, E=E))
Element.append(tp.Element(node[5-1], node[6-1], A=A, E=E))
Element.append(tp.Element(node[5-1], node[7-1], A=A, E=E))
Element.append(tp.Element(node[6-1], node[7-1], A=A, E=E))
Element.append(tp.Element(node[6-1], node[8-1], A=A, E=E))
Element.append(tp.Element(node[6-1], node[15-1], A=A, E=E))
Element.append(tp.Element(node[8-1], node[15-1], A=A, E=E))
Element.append(tp.Element(node[7-1], node[8-1], A=A, E=E))
Element.append(tp.Element(node[7-1], node[9-1], A=A, E=E))
Element.append(tp.Element(node[8-1], node[9-1], A=A, E=E))
Element.append(tp.Element(node[8-1], node[10-1], A=A, E=E))
Element.append(tp.Element(node[9-1], node[10-1], A=A, E=E))
Element.append(tp.Element(node[10-1], node[11-1], A=A, E=E))
Element.append(tp.Element(node[10-1], node[13-1], A=A, E=E))
Element.append(tp.Element(node[8-1], node[13-1], A=A, E=E))
Element.append(tp.Element(node[11-1], node[13-1], A=A, E=E))
Element.append(tp.Element(node[13-1], node[14-1], A=A, E=E))
Element.append(tp.Element(node[11-1], node[14-1], A=A, E=E))
Element.append(tp.Element(node[8-1], node[14-1], A=A, E=E))
Element.append(tp.Element(node[11-1], node[12-1], A=A, E=E))
Element.append(tp.Element(node[12-1], node[14-1], A=A, E=E))
Element.append(tp.Element(node[12-1], node[1-1], A=A, E=E))
Element.append(tp.Element(node[14-1], node[1-1], A=A, E=E))
Element.append(tp.Element(node[14-1], node[16-1], A=A, E=E))
Element.append(tp.Element(node[15-1], node[16-1], A=A, E=E))
Element.append(tp.Element(node[1-1], node[16-1], A=A, E=E))
Element.append(tp.Element(node[16-1], node[20-1], A=A, E=E))
Element.append(tp.Element(node[2-1], node[20-1], A=A, E=E))
Element.append(tp.Element(node[1-1], node[2-1], A=A, E=E))
Element.append(tp.Element(node[1-1], node[3-1], A=A, E=E))
Element.append(tp.Element(node[1-1], node[22-1], A=A, E=E))
Element.append(tp.Element(node[2-1], node[3-1], A=A, E=E))
Element.append(tp.Element(node[3-1], node[20-1], A=A, E=E))
Element.append(tp.Element(node[3-1], node[21-1], A=A, E=E))
Element.append(tp.Element(node[3-1], node[22-1], A=A, E=E))
Element.append(tp.Element(node[20-1], node[21-1], A=A, E=E))
Element.append(tp.Element(node[21-1], node[22-1], A=A, E=E))
Element.append(tp.Element(node[14-1], node[15-1], A=A, E=E))
Element.append(tp.Element(node[16-1], node[2-1], A=A, E=E))

# %% [markdown]
# # Make K for Elements

# %%
Element[1-1].make_element_K_with_help(node[17-1], node[18-1])
Element[2-1].make_element_K_with_help(node[18-1], node[19-1])
Element[3-1].make_element_K_with_help(node[4-1], node[18-1])
Element[4-1].make_element_K_with_help(node[4-1], node[19-1])
Element[5-1].make_element_K_with_help(node[4-1], node[17-1])
Element[6-1].make_element_K_with_help(node[7-1], node[17-1])
Element[7-1].make_element_K_with_help(node[5-1], node[19-1])
Element[8-1].make_element_K_with_help(node[4-1], node[5-1])
Element[9-1].make_element_K_with_help(node[4-1], node[7-1])
Element[10-1].make_element_K_with_help(node[6-1], node[19-1])
Element[11-1].make_element_K_with_help(node[5-1], node[6-1])
Element[12-1].make_element_K_with_help(node[5-1], node[7-1])
Element[13-1].make_element_K_with_help(node[6-1], node[7-1])
Element[14-1].make_element_K_with_help(node[6-1], node[8-1])
Element[15-1].make_element_K_with_help(node[6-1], node[15-1])
Element[16-1].make_element_K_with_help(node[8-1], node[15-1])
Element[17-1].make_element_K_with_help(node[7-1], node[8-1])
Element[18-1].make_element_K_with_help(node[7-1], node[9-1])
Element[19-1].make_element_K_with_help(node[8-1], node[9-1])
Element[20-1].make_element_K_with_help(node[8-1], node[10-1])
Element[21-1].make_element_K_with_help(node[9-1], node[10-1])
Element[22-1].make_element_K_with_help(node[10-1], node[11-1])
Element[23-1].make_element_K_with_help(node[10-1], node[13-1])
Element[24-1].make_element_K_with_help(node[8-1], node[13-1])
Element[25-1].make_element_K_with_help(node[11-1], node[13-1])
Element[26-1].make_element_K_with_help(node[13-1], node[14-1])
Element[27-1].make_element_K_with_help(node[11-1], node[14-1])
Element[28-1].make_element_K_with_help(node[8-1], node[14-1])
Element[29-1].make_element_K_with_help(node[11-1], node[12-1])
Element[30-1].make_element_K_with_help(node[12-1], node[14-1])
Element[31-1].make_element_K_with_help(node[12-1], node[1-1])
Element[32-1].make_element_K_with_help(node[14-1], node[1-1])
Element[33-1].make_element_K_with_help(node[14-1], node[16-1])
Element[34-1].make_element_K_with_help(node[15-1], node[16-1])
Element[35-1].make_element_K_with_help(node[1-1], node[16-1])
Element[36-1].make_element_K_with_help(node[16-1], node[20-1])
Element[37-1].make_element_K_with_help(node[2-1], node[20-1])
Element[38-1].make_element_K_with_help(node[1-1], node[2-1])
Element[39-1].make_element_K_with_help(node[1-1], node[3-1])
Element[40-1].make_element_K_with_help(node[1-1], node[22-1])
Element[41-1].make_element_K_with_help(node[2-1], node[3-1])
Element[42-1].make_element_K_with_help(node[3-1], node[20-1])
Element[43-1].make_element_K_with_help(node[3-1], node[21-1])
Element[44-1].make_element_K_with_help(node[3-1], node[22-1])
Element[45-1].make_element_K_with_help(node[20-1], node[21-1])
Element[46-1].make_element_K_with_help(node[21-1], node[22-1])
Element[47-1].make_element_K_with_help(node[14-1], node[15-1])
Element[48-1].make_element_K_with_help(node[16-1], node[2-1])

# %% [markdown]
# #### Step 1: make total K as "K"

# %%
K = np.zeros(44 * 44)  # n*n total
K_help = tp.make_K_help(44)  # n total
print(K_help)
for i in range(len(Element)):
    K = Element[i].merge_K(K, K_help)
# print(K.reshape((44 * 44)))
# Out:
# ['01x01x' '01x01y' '01x02x' '01x02y' '01x03x' '01x03y' '01x04x' '01x04y'
#  '01x05x' '01x05y' '01x06x' '01x06y' '01x07x' '01x07y' '01x08x' '01x08y'
#  '01x09x' '01x09y' '01x010x' '01x010y' '01x011x' '01x011y' '01x012x'
#  '01x012y' '01x013x' '01x013y' '01x014x' '01x014y' '01x015x' '01x015y'
#  '01x016x' '01x016y' '01x017x' '01x017y' '01x018x' '01x018y' '01x019x'
#  '01x019y' '01x020x' '01x020y' '01x021x' '01x021y' '01x022x' '01x022y'
#  '01y01x' '01y01y' '01y02x' '01y02y' '01y03x' '01y03y' '01y04x' '01y04y'
#  '01y05x' '01y05y' '01y06x' '01y06y' '01y07x' '01y07y' '01y08x' '01y08y'
#  '01y09x' '01y09y' '01y010x' '01y010y' '01y011x' '01y011y' '01y012x'
#  '01y012y' '01y013x' '01y013y' '01y014x' '01y014y' '01y015x' '01y015y'
#  '01y016x' '01y016y' '01y017x' '01y017y' '01y018x' '01y018y' '01y019x'
#  '01y019y' '01y020x' '01y020y' '01y021x' '01y021y' '01y022x' '01y022y'
#  '02x01x' '02x01y' '02x02x' '02x02y' '02x03x' '02x03y' '02x04x' '02x04y'
# ...

# %% [markdown]
# #### Step 2: make modified K as "K_modifide"

# %%
K_modified = np.array([])
new_K_help = tp.make_K_help(32, 1, 1)  # show where is the modified K
for p, v in np.ndenumerate(K_help):
    if v in new_K_help:
        K_modified = np.append(K_modified, K[p])

K_modified = K_modified.reshape([32, 32])  # shape the modified.
print(str(K_modified))
# Out:
# [[ 5.35789090e+08  8.87222412e+07  0.00000000e+00  0.00000000e+00
#   -1.64025741e+07  7.21713260e+07  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 8.87222412e+07  2.57096533e+09  0.00000000e+00 -7.53440000e+08
#    7.21713260e+07 -3.17553834e+08  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
# ...

# %% [markdown]
# ### F = K*D
# #### find displacements as "displacements"

# %%
K_modified_inv = np.linalg.inv(K_modified)
F = np.zeros(32)
F[12] = 1500
F[16] = 1500
F[17] = -1000
F[19] = -1000
F[21] = -1000
F[23] = -1000
# print(F)
F_show = F.reshape((32, 1))
# print(F_show)
# F = np.array([[0], [0], [0], [0], [0], ])  # Enter F matrix modified
displacements = np.dot(K_modified_inv, F_show)
# for i in range(len(displacements)):
#     if displacements[i] < 0.00000000001:
#         displacements[i] = 0

displacements_show = displacements * 100 /2.54
print(str(displacements_show))
# Out:
# [[ 3.48479793e-22]
#  [-1.58223307e-21]
#  [-1.12636114e-20]
#  [-5.08744675e-21]
#  [ 2.91555537e-23]
#  [-6.35351784e-22]
#  [-2.79974499e-06]
#  [-9.77020080e-06]
#  [ 1.32274323e-04]
#  [-7.40526834e-05]
#  [ 2.04844847e-04]
#  [-1.49095525e-04]
#  [ 3.42397812e-04]
#  [-1.07967304e-04]
#  [ 3.74304775e-05]
#  [-3.46515309e-05]
#  [ 1.39571157e-04]
#  [-1.47495816e-04]
#  [ 1.12202298e-04]
#  [-9.32122704e-05]
#  [ 1.20449945e-04]
#  [-1.17278190e-04]
#  [ 1.31440622e-04]
#  [-1.07769503e-04]
#  [ 4.31999301e-05]
#  [-6.21240270e-05]
#  [ 3.55890066e-05]
#  [-4.07860949e-05]
#  [ 4.88519600e-05]
#  [-1.14474465e-05]
#  [ 1.45184115e-05]
#  [-1.35155250e-05]]

# %%
displacements_total = np.zeros(44)  # total dimension, rows or columns
iteration = -1
temp = 0
new2_K_help = new_K_help.copy()
new2_K_help = new2_K_help[
              0:-1:32]  # n(the last number in parentheses) is the number of dimension in matrix, the dimension of new_K_help
# print(len(K_help))
for i in range(len(new2_K_help)):
    new2_K_help[i] = new2_K_help[i][0:2]
for p, v in np.ndenumerate(K_help):
    if temp == v[0:2]:
        continue
    temp = v[0:2]
    if v[0:2] in new2_K_help:
        iteration += 1
        displacements_total[(p[0] // 44)] = displacements[
            iteration]  # n is the dimension of main matrix... total K dimension
K = K.reshape([44, 44])  # n*n total
displacements_total = displacements_total.reshape((44, 1))
F_total = np.dot(K, displacements_total)
# print(F_total)
print(displacements_total)
# Out:
# [[0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [3.35976780e-06]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [5.20305911e-06]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [8.69690442e-06]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [9.50734130e-07]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]]

# %% [markdown]
# ### F = K*D
# #### find Forces as "F_total"
