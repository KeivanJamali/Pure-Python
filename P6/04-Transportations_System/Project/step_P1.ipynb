# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # P0

# %%
from modular.extract_network import Graph
network = Graph()

# %% [markdown]
# # P1 - All or Nothing Assignment

# %%
from modular.simple_assignments import engine
from modular.extract_network import Graph
network = Graph()
st_number = "403206113"
algorithm = engine(network, st_number, init_flow=0, init_capacity=1000)
algorithm.run_allornothing()
print("Important Number is:", algorithm.get_important_number())
# algorithm.network.plot("flow")
# Out:
# [INFO] Success All Or Nothing Assignment!!!
# Important Number is: 378841

# %% [markdown]
# # P2 - Incremental assignment

# %% [markdown]
# ## P2.1 - with fixed steps

# %%
from modular.extract_network import Graph
from modular.simple_assignments import engine
network = Graph()
algorithm = engine(graph=network, student_id="403209743", init_flow=0, init_capacity=1000)
algorithm.run_incremental_fixed(fixed_n=10)
print("Important Number is:", algorithm.get_important_number())
algorithm.network.plot("flow")
# Out:
# [INFO] Success Incremental Assignment after 10 steps!!!
# Important Number is: 360781

# %% [markdown]
# ## P2.2 with fixed steps and percentage

# %%
from modular.extract_network import Graph
from modular.simple_assignments import engine
network = Graph()
algorithm = engine(graph=network, student_id="403209743", init_flow=0, init_capacity=1000)
algorithm.run_incremental_fixed_with_percentage(fixed_n=20, percentage=0.1)
algorithm.network.plot("flow")
algorithm.get_result_as_file("test.txt")
# Out:
# [INFO] Success Incremental Assignment after 20 steps total assign of=0.8784233454094309% !!!
# [INFO] File test.txt created successfully.

# %% [markdown]
# ## P2.3 - with only percentage and criteria

# %%
from modular.extract_network import Graph
from modular.simple_assignments import engine
network = Graph()
algorithm = engine(graph=network, student_id="403209743", init_flow=0, init_capacity=1000)
algorithm.run_incremental_percentage(percentage=0.1, threshold=1e-6)
print(algorithm.get_total_flow())
algorithm.network.plot("flow")

# algorithm.get_result_as_file("test.txt")
# Out:
# [INFO] Success Incremental Assignment after 110 steps total assign of=0.9999907386128697% !!!
# 1289.3

# %%
532/76
# Out:
# 7.0
