# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("data.csv")
data
# Out:
#     Year  Electricity (Million kilowatt-hour)
# 0   1344                                  816
# 1   1345                                 1062
# 2   1346                                 1409
# 3   1347                                 1924
# 4   1348                                 2562
# 5   1349                                 3418
# 6   1350                                 4519
# 7   1351                                 5723
# 8   1352                                 7796
# 9   1353                                 9152
# 10  1354                                10447
# 11  1355                                11734
# 12  1356                                13066
# 13  1357                                14145
# 14  1358                                15917
# 15  1359                                16383
# 16  1360                                18234
# 17  1361                                21753
# 18  1362                                25153
# ...

# %%
plt.scatter(data["Year"], data["Electricity (Million kilowatt-hour)"])
plt.title("Domestic sale of Electricity from 1344 to 1396.")
plt.xlabel("Year")
plt.ylabel("Electricity (Million Kilowatt-hour)")
plt.show()
