# %%
import sympy as sp
import matplotlib.pyplot as plt
import numpy as np

# %%
p1 = [15, 12, 10, 8, 7, 6, 5, 4]
p2 = [20, 16, 13, 11, 9, 8, 7, 7]
p3 = [18, 15, 12, 10, 9, 8, 7, 6]
p4 = [25, 21, 18, 16, 14, 12, 11, 10]

x = list(range(0, 36, 5))

# %%
plt.plot(x, p1)
plt.plot(x, p2)
plt.plot(x, p3)
plt.plot(x, p4)
plt.savefig("plot.png")

# %%
min(33+25, 35+21, 37+18, 40+16, 43+14, 46+12, 49+11, 53+10)
# Out:
# 55
