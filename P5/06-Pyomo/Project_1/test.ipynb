# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd

data = pd.read_csv("sensitivity_parameters.csv")

# %%
mask = data["scenario_type"] == "volatility"
data[mask]
# Out:
#       run_id   T  L   C   p    h   w    s  demand_t1  demand_t2  ...  \
# 0          1  10  3  30  20  2.0  50  300         30         14  ...
# 1          2  10  3  30  20  2.0  50  300         29         14  ...
# 2          3  10  3  30  20  2.0  50  300         32         14  ...
# 3          4  10  3  30  20  2.0  50  300         29         16  ...
# 4          5  10  3  30  20  2.0  50  300         31         15  ...
# ...      ...  .. ..  ..  ..  ...  ..  ...        ...        ...  ...
# 2495    2496  10  3  30  20  2.0  50  300         12         10  ...
# 2496    2497  10  3  30  20  2.0  50  300         28          9  ...
# 2497    2498  10  3  30  20  2.0  50  300         14          2  ...
# 2498    2499  10  3  30  20  2.0  50  300         47         11  ...
# 2499    2500  10  3  30  20  2.0  50  300         19          2  ...
#
#       capacity_t1  capacity_t2  capacity_t3  capacity_t4  capacity_t5  \
# ...
