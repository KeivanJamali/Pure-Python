# %%
import pandas as pd
import numpy as np

# %%
data_people = pd.read_excel(r"/mnt/Data1/Python_Projects/Pure-Python/P5/Thesis/data/Shiraz94/People.xlsx")
data_people
# Out:
#        کد پرسشنامه  شماره فرد جنسیت  سن        شغل وضعیت اشتغال  \
# 0         11019516          1   مرد  58   بازنشسته      غیرشاغل
# 1         11019516          2    زن  52   بازنشسته      غیرشاغل
# 2         11019516          3   مرد  29     کارمند         شاغل
# 3         11019516          4    زن  27      بیکار      غیرشاغل
# 4         11019516          5   مرد  13  دانش آموز      غیرشاغل
# ...            ...        ...   ...  ..        ...          ...
# 61017     21034757          5   مرد  13  دانش آموز      غیرشاغل
# 61018     21034778          1    زن  70   خانه دار      غیرشاغل
# 61019     21034778          2   مرد  36     کارمند         شاغل
# 61020     21034773          1   مرد  65   بازنشسته      غیرشاغل
# 61021     21034773          2    زن  56   خانه دار      غیرشاغل
#
#       گواهینامه رانندگی سطح تحصیلات  کد ناحیه منزل  کد منطقه منزل
# 0                  دارد   فوق دیپلم            212             10
# ...

# %%
data_family = pd.read_excel(r"/mnt/Data1/Python_Projects/Pure-Python/P5/Thesis/data/Shiraz94/Family.xlsx")
data_family
# Out:
#        کد پرسشنامه  تعداد افراد خانواده  تعداد کل وسایل نفلیه  \
# 0         11010014                    6                     0
# 1         11010080                    5                     1
# 2         11010117                    3                     1
# 3         11010152                    4                     2
# 4         11010157                    4                     2
# ...            ...                  ...                   ...
# 18639     32318106                    1                     1
# 18640     32318107                    1                     1
# 18641     32318108                    1                     0
# 18642     32318109                    1                     1
# 18643     32318110                    1                     1
#
#        تعداد دوچرخه 24 و بالاتر  تعداد موتورسیکلت  تعداد سواری شخصی  \
# 0                             0                 0                 0
# 1                             1                 0                 0
# ...

# %%
data_trips = pd.read_excel(r"/mnt/Data1/Python_Projects/Pure-Python/P5/Thesis/data/Shiraz94/Trips.xlsx")
data_trips
# Out:
#        کد سفر  کد پرسشنامه  شماره فرد  کد ناحیه منزل  کد منطقه منزل  \
# 0      120670     11010014          1            252             14
# 1      120671     11010014          1            252             14
# 2      100368     11010080          1            171             14
# 3      100370     11010080          1            171             14
# 4      100371     11010080          1            171             14
# ...       ...          ...        ...            ...            ...
# 93936  107679     32318109          1             27              1
# 93937  107672     32318110          1             27              1
# 93938  107673     32318110          1             27              1
# 93939  107674     32318110          1             27              1
# 93940  107675     32318110          1             27              1
#
#        کد ناحیه مبدا سفر  کد منطقه مبدا سفر  کد ناحیه مقصد سفر  \
# 0                    252                 14                128
# ...
