# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import HW2_toolkit as tl
from HW2_toolkit import Forcasting_Formulas

# %% [markdown]
# # Q1

# %%
data = pd.read_csv("data.csv")
model = Forcasting_Formulas(data=data)
model.data
# Out:
#        0       1
# 0   1344     816
# 1   1345    1062
# 2   1346    1409
# 3   1347    1924
# 4   1348    2562
# 5   1349    3418
# 6   1350    4519
# 7   1351    5723
# 8   1352    7796
# 9   1353    9152
# 10  1354   10447
# 11  1355   11734
# 12  1356   13066
# 13  1357   14145
# 14  1358   15917
# 15  1359   16383
# 16  1360   18234
# 17  1361   21753
# 18  1362   25153
# 19  1363   28176
# 20  1364   30812
# 21  1365   32619
# 22  1366   34740
# 23  1367   36147
# 24  1368   39956
# 25  1369   45107
# 26  1370   48757
# 27  1371   52306
# 28  1372   58114
# 29  1373   63625
# 30  1374   65854
# 31  1375   69671
# 32  1376   73358
# 33  1377   77646
# 34  1378   84656
# 35  1379   90366
# 36  1380   97171
# 37  1381  105064
# 38  1382  114625
# 39  1383  125528
# 40  1384  132898
# 41  1385  144581
# 42  1386  152329
# 43  1387  161445
# 44  1388  168432
# 45  1389  184182
# 46  1390  183905
# 47  1391  194149
# 48  1392  203088
# 49  1393  219653
# 50  1394  227312
# 51  1395  237436
# 52  1396  255026

# %%
Forcasting_Formulas.plotting(data=data, data_name="Data")

# %% [markdown]
# ### Simple Moving Average - 3 years

# %%
name = "Simple Moving Average - 3 years"
model = tl.Forcasting_Formulas(data=data)
small_data, total_data = model.simple_moving_average(number_of_data=3, number_of_prediction=6)
small_data
# Out:
#       0              1
# 1  1394  227312.000000
# 2  1395  237436.000000
# 3  1396  255026.000000
# 4  1397  239924.666667
# 5  1398  244128.888889
# 6  1399  246359.851852
# 7  1400  243471.135802
# 8  1401  244653.292181
# 9  1402  244828.093278

# %%
model.plotting(data=total_data, data_name=name)

# %% [markdown]
# ### Simple Moving Average - 5 years

# %%
name = "Simple Moving Average - 5 years"
small_data, total_data = model.simple_moving_average(number_of_data=5, number_of_prediction=6)
model.plotting(data=total_data, data_name=name)
print(small_data)
# Out:
#        0            1
# 1   1392  203088.0000
# 2   1393  219653.0000
# 3   1394  227312.0000
# 4   1395  237436.0000
# 5   1396  255026.0000
# 6   1397  228503.0000
# 7   1398  233586.0000
# 8   1399  236372.6000
# 9   1400  238184.7200
# 10  1401  238334.4640
# 11  1402  234996.1568

# %% [markdown]
# ### Simple Moving Average - 7 years

# %%
name = "Simple Moving Average - 7 years"
small_data, total_data = model.simple_moving_average(number_of_data=7, number_of_prediction=6)
model.plotting(data=total_data, data_name=name)
print(small_data)
# Out:
#        0              1
# 1   1390  183905.000000
# 2   1391  194149.000000
# 3   1392  203088.000000
# 4   1393  219653.000000
# 5   1394  227312.000000
# 6   1395  237436.000000
# 7   1396  255026.000000
# 8   1397  217224.142857
# 9   1398  221984.020408
# 10  1399  225960.451895
# 11  1400  229227.945023
# 12  1401  230595.794312
# 13  1402  231064.907785

# %% [markdown]
# ### Simple Moving Average - 9 years

# %%
name = "Simple Moving Average - 9 years"
small_data, total_data = model.simple_moving_average(number_of_data=9, number_of_prediction=6)
model.plotting(data=total_data, data_name=name)
print(small_data)
# Out:
#        0              1
# 1   1388  168432.000000
# 2   1389  184182.000000
# 3   1390  183905.000000
# 4   1391  194149.000000
# 5   1392  203088.000000
# 6   1393  219653.000000
# 7   1394  227312.000000
# 8   1395  237436.000000
# 9   1396  255026.000000
# 10  1397  208131.444444
# 11  1398  212542.493827
# 12  1399  215693.659808
# 13  1400  219225.733120
# 14  1401  222012.036800
# 15  1402  224114.707555

# %% [markdown]
# ### Weighted Moving Average - 3 years

# %%
name = "Weighted Moving Average - 3 years"
small_data, total_data, = model.weighted_moving_average(number_of_data=3,weights=[0.5,0.33,0.17], number_of_prediction=6)
model.plotting(data=total_data, data_name=name)
print(small_data)
# Out:
#       0              1
# 1  1394  227312.000000
# 2  1395  237436.000000
# 3  1396  255026.000000
# 4  1397  235364.300000
# 5  1398  242888.511000
# 6  1399  246474.265870
# 7  1400  239735.983828
# 8  1401  243535.880488
# 9  1402  243751.107281
