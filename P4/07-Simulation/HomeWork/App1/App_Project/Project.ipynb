# %%
from modular.main import main

model = main(policy="FCFS",
             stop_type="Customer",
             stop_limit=7,
             queue_type="MDI",
             plot_it=True)
# Out:
# ...
#
# Therefore, Average waiting time for People in Queue (Q_bar) will be 3.24
# Therefore, Average number of People in Queue (N_Q) will be 0.81
# We have 5 people with more that 4.5 min system time. Therefore the percentage is 71.43
# Therefore the U=94.30
#
# ...
