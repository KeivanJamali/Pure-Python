# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from modular.Multirun_Engine import Queue_Program
from Simulation_ToolKit import Validation

# %%
seed1 = [2062615503, 1, 2, 3, 4, 5, 6, 7, 8, 9]
seed2 = [1383670351, 11111, 22222, 33333, 44444, 55555, 66666, 77777, 88888, 99999]
seed_pairs = list(zip(seed1, seed2))
mean_0 = [5, 5.5, 6, 6.5, 7, 7.5, 8, 8.5, 9, 9.5, 10]
good_ones = []
for i in range(len(mean_0)):
    sigma_model1 = Queue_Program(seed_pairs=seed_pairs,
                                 mean_pair=[mean_0[i], 4.5],
                                 generator_pair=["Expo", "Deter"],
                                 sim_time_limit=float("inf"),
                                 sim_customer_limit=1000,
                                 capacity=1,
                                 policy="FCFS")
    sigma_model1.run()
    data1 = [list(sigma_model1.result["wait_time_queue"].values),
            list(sigma_model1.result["wait_time_system"].values),
            list(sigma_model1.result["number_system"].values)]
    
    sigma_model2 = Queue_Program(seed_pairs=seed_pairs,
                                 mean_pair=[mean_0[i], 4],
                                 generator_pair=["Expo", "Expo"],
                                 sim_time_limit=float("inf"),
                                 sim_customer_limit=1000,
                                 capacity=1,
                                 policy="FCFS")
    sigma_model2.run()
    data2 = [list(sigma_model2.result["wait_time_queue"].values),
            list(sigma_model2.result["wait_time_system"].values),
            list(sigma_model2.result["number_system"].values)]
    valid = Validation.Validation_Tools(data_list=[data1[0], data1[1], data1[2], data2[0], data2[1], data2[2]],
                                    name_list=["data1_0", "data1_1", "data1_2", "data2_0", "data2_1", "data2_2"])
    r1 = valid.common_random_numbers(data_name_1="data1_0", data_name_2="data2_0", alpha=0.1)
    r2 = valid.common_random_numbers(data_name_1="data1_1", data_name_2="data2_1", alpha=0.1)
    r3 = valid.common_random_numbers(data_name_1="data1_2", data_name_2="data2_2", alpha=0.1)
    if r1["confidence_intervals"]["90.000%"][1] < 0:
        if r2["confidence_intervals"]["90.000%"][1] < 0:
             if r3["confidence_intervals"]["90.000%"][1] < 0:
                good_ones.append(mean_0[i])
# Out:
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] 'data1_0' data added to the storage with Mean:22.978647222120934 and Variance:111.57556721693726.
# [INFO] 'data1_1' data added to the storage with Mean:27.47864722212093 and Variance:111.57556721693724.
# [INFO] 'data1_2' data added to the storage with Mean:5.655874483958871 and Variance:5.611530692193108.
# [INFO] 'data2_0' data added to the storage with Mean:15.936920862345058 and Variance:13.163738847267899.
# [INFO] 'data2_1' data added to the storage with Mean:19.95041527390179 and Variance:13.300545128659815.
# [INFO] 'data2_2' data added to the storage with Mean:4.087154127017678 and Variance:0.6792272764366454.
# [RESULT] [2.200826, 11.882627]
# [RESULT] [2.664612, 12.391852]
# [RESULT] [0.521705, 2.615736]
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] 'data1_0' data added to the storage with Mean:10.782589675301342 and Variance:12.523039753145436.
# [INFO] 'data1_1' data added to the storage with Mean:15.282589675301347 and Variance:12.523039753145422.
# [INFO] 'data1_2' data added to the storage with Mean:2.849240641297494 and Variance:0.552665220759726.
# [INFO] 'data2_0' data added to the storage with Mean:10.509225018972483 and Variance:4.056467466907071.
# [INFO] 'data2_1' data added to the storage with Mean:14.522719430529225 and Variance:4.148736304285325.
# [INFO] 'data2_2' data added to the storage with Mean:2.7030955504107057 and Variance:0.19064163771394174.
# [RESULT] [-0.985440, 1.532169]
# [RESULT] [-0.531768, 2.051509]
# [RESULT] [-0.102733, 0.395023]
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] 'data1_0' data added to the storage with Mean:7.0820182726933725 and Variance:3.587582587520625.
# [INFO] 'data1_1' data added to the storage with Mean:11.58201827269337 and Variance:3.5875825875206377.
# [INFO] 'data1_2' data added to the storage with Mean:1.977075595845779 and Variance:0.1416568832094388.
# [INFO] 'data2_0' data added to the storage with Mean:7.953150922914951 and Variance:2.3177491012776206.
# [INFO] 'data2_1' data added to the storage with Mean:11.96664533447168 and Variance:2.397538953675687.
# [INFO] 'data2_2' data added to the storage with Mean:2.040674919884931 and Variance:0.09160531156736751.
# [RESULT] [-1.484743, -0.257522]
# [RESULT] [-1.035828, 0.266574]
# [RESULT] [-0.175406, 0.048207]
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] 'data1_0' data added to the storage with Mean:5.211074877802692 and Variance:1.1127188846066616.
# [INFO] 'data1_1' data added to the storage with Mean:9.711074877802695 and Variance:1.1127188846066527.
# [INFO] 'data1_2' data added to the storage with Mean:1.5289032775167581 and Variance:0.041860053316196195.
# [INFO] 'data2_0' data added to the storage with Mean:6.376949254025707 and Variance:1.3236147545207606.
# [INFO] 'data2_1' data added to the storage with Mean:10.390443665582438 and Variance:1.4048016212075047.
# [INFO] 'data2_2' data added to the storage with Mean:1.6347369693178908 and Variance:0.04581392156497984.
# [RESULT] [-1.610817, -0.720932]
# [RESULT] [-1.161543, -0.197195]
# [RESULT] [-0.180575, -0.031092]
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] 'data1_0' data added to the storage with Mean:4.132758253596238 and Variance:0.41250925009871353.
# [INFO] 'data1_1' data added to the storage with Mean:8.632758253596238 and Variance:0.4125092500987116.
# [INFO] 'data1_2' data added to the storage with Mean:1.26155228505601 and Variance:0.015487729850335606.
# [INFO] 'data2_0' data added to the storage with Mean:5.282152968059819 and Variance:0.7268325762431727.
# [INFO] 'data2_1' data added to the storage with Mean:9.295647379616549 and Variance:0.8016528944984507.
# [INFO] 'data2_2' data added to the storage with Mean:1.3579361494587727 and Variance:0.023468988239276463.
# [RESULT] [-1.513837, -0.784953]
# [RESULT] [-1.064587, -0.261191]
# [RESULT] [-0.154135, -0.038632]
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] 'data1_0' data added to the storage with Mean:3.438983816389853 and Variance:0.1917557729696261.
# [INFO] 'data1_1' data added to the storage with Mean:7.938983816389855 and Variance:0.191755772969626.
# [INFO] 'data1_2' data added to the storage with Mean:1.0826254693407191 and Variance:0.007333404147805618.
# [INFO] 'data2_0' data added to the storage with Mean:4.4910735407355205 and Variance:0.3945969499443349.
# [INFO] 'data2_1' data added to the storage with Mean:8.504567952292252 and Variance:0.46565420202630825.
# [INFO] 'data2_2' data added to the storage with Mean:1.1596219330936026 and Variance:0.012842018683037026.
# [RESULT] [-1.331597, -0.772583]
# [RESULT] [-0.885748, -0.245421]
# [RESULT] [-0.120083, -0.033910]
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] 'data1_0' data added to the storage with Mean:2.938682223585336 and Variance:0.09609932316418779.
# [INFO] 'data1_1' data added to the storage with Mean:7.438682223585337 and Variance:0.09609932316418807.
# [INFO] 'data1_2' data added to the storage with Mean:0.9508717875304831 and Variance:0.003882588184422072.
# [INFO] 'data2_0' data added to the storage with Mean:3.919583421966118 and Variance:0.2324838079064624.
# [INFO] 'data2_1' data added to the storage with Mean:7.933077833522852 and Variance:0.29729111644930195.
# [INFO] 'data2_2' data added to the storage with Mean:1.0139653339912316 and Variance:0.0075037357315306565.
# [RESULT] [-1.229032, -0.732770]
# [RESULT] [-0.782013, -0.206778]
# [RESULT] [-0.099335, -0.026852]
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] 'data1_0' data added to the storage with Mean:2.563407191341013 and Variance:0.05110427759292107.
# [INFO] 'data1_1' data added to the storage with Mean:7.063407191341014 and Variance:0.051104277592921216.
# [INFO] 'data1_2' data added to the storage with Mean:0.8496880203607093 and Variance:0.0022554550051005267.
# [INFO] 'data2_0' data added to the storage with Mean:3.4773120993685587 and Variance:0.14609792731557558.
# [INFO] 'data2_1' data added to the storage with Mean:7.490806510925291 and Variance:0.20533730533106165.
# [INFO] 'data2_2' data added to the storage with Mean:0.9010236160413575 and Variance:0.004768105337383017.
# [RESULT] [-1.130505, -0.697305]
# [RESULT] [-0.683184, -0.171615]
# [RESULT] [-0.081668, -0.021003]
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] 'data1_0' data added to the storage with Mean:2.2677752426248228 and Variance:0.0341936349797205.
# [INFO] 'data1_1' data added to the storage with Mean:6.767775242624824 and Variance:0.03419363497972029.
# [INFO] 'data1_2' data added to the storage with Mean:0.7688743035949712 and Variance:0.0015867953239072777.
# [INFO] 'data2_0' data added to the storage with Mean:3.133867541969305 and Variance:0.10316375604147547.
# [INFO] 'data2_1' data added to the storage with Mean:7.147361953526035 and Variance:0.1559312274088649.
# [INFO] 'data2_2' data added to the storage with Mean:0.8119222626572297 and Variance:0.0033727333751100816.
# [RESULT] [-1.057224, -0.674960]
# [RESULT] [-0.608125, -0.151048]
# [RESULT] [-0.068622, -0.017474]
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] 'data1_0' data added to the storage with Mean:2.0280307982902963 and Variance:0.024603162899730958.
# [INFO] 'data1_1' data added to the storage with Mean:6.528030798290297 and Variance:0.02460316289973093.
# [INFO] 'data1_2' data added to the storage with Mean:0.7025874900803318 and Variance:0.0011962514650022066.
# [INFO] 'data2_0' data added to the storage with Mean:2.8538932011562315 and Variance:0.07815822168069801.
# [INFO] 'data2_1' data added to the storage with Mean:6.867387612712962 and Variance:0.12494619003203183.
# [INFO] 'data2_2' data added to the storage with Mean:0.7390655394226805 and Variance:0.0025711978187324385.
# [RESULT] [-0.992166, -0.659559]
# [RESULT] [-0.542266, -0.136448]
# [RESULT] [-0.057978, -0.014978]
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] 'data1_0' data added to the storage with Mean:1.8326197218426272 and Variance:0.019298567533583357.
# [INFO] 'data1_1' data added to the storage with Mean:6.332619721842627 and Variance:0.0192985675335833.
# [INFO] 'data1_2' data added to the storage with Mean:0.647467780273946 and Variance:0.0009406052752695726.
# [INFO] 'data2_0' data added to the storage with Mean:2.615452351960018 and Variance:0.06022307017093842.
# [INFO] 'data2_1' data added to the storage with Mean:6.6289467635167485 and Variance:0.10223761461875999.
# [INFO] 'data2_2' data added to the storage with Mean:0.677727402010224 and Variance:0.002005225624263209.
# [RESULT] [-0.929773, -0.635892]
# [RESULT] [-0.479744, -0.112910]
# [RESULT] [-0.048717, -0.011802]

# %%
good_ones
# Out:
# [6.5, 7, 7.5, 8, 8.5, 9, 9.5, 10]

# %%
sigma_model2 = Queue_Program(seed_pairs=seed_pairs,
                            mean_pairs=[5, 4],
                            sim_time_limit=float("inf"),
                            sim_customer_limit=100,
                            policy="FCFS",
                            capacity=1)

sigma_model2.run()
data2 = [list(sigma_model2.result["wait_time_queue"].values),
         list(sigma_model2.result["wait_time_system"].values),
         list(sigma_model2.result["number_system"].values)]
# Out:
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.
# [INFO] Customer limit reached. The simulation finished successfuly.

# %%
valid = Validation.Validation_Tools(data_list=[data1[0], data1[1], data1[2], data2[0], data2[1], data2[2]],
                                    name_list=["data1_0", "data1_1", "data1_2", "data2_0", "data2_1", "data2_2"])
# Out:
# [INFO] 'data1_0' data added to the storage with Mean:12.233142157181282 and Variance:53.36490329177746.
# [INFO] 'data1_1' data added to the storage with Mean:16.733142157181284 and Variance:53.36490329177748.
# [INFO] 'data1_2' data added to the storage with Mean:3.414975186464967 and Variance:2.973417199260942.
# [INFO] 'data2_0' data added to the storage with Mean:11.741337194447095 and Variance:35.05593228554373.
# [INFO] 'data2_1' data added to the storage with Mean:15.820925950912786 and Variance:38.08262938746176.
# [INFO] 'data2_2' data added to the storage with Mean:3.273249101018581 and Variance:2.069717645569025.

# %%
sigma_model2.result
# Out:
#    total_time  arrived  ...  number_system                 seed_pair
# 0  459.001629      100  ...       2.961752  (2062615503, 1383670351)
# 1  541.226983      101  ...       1.502948                (1, 11111)
# 2  526.987052      109  ...       2.904469                (2, 22222)
# 3  531.864997      101  ...       2.953895                (3, 33333)
# 4  559.844002      105  ...       2.544945                (4, 44444)
# 5  510.578009      101  ...       4.229887                (5, 55555)
# 6  510.942097      105  ...       1.895719                (6, 66666)
# 7  522.882827      103  ...       3.572617                (7, 77777)
# 8  432.290769      100  ...       6.691599                (8, 88888)
# 9  501.695813      105  ...       3.474659                (9, 99999)
#
# [10 rows x 7 columns]

# %%
r1 = valid.common_random_numbers(data_name_1="data1_0", data_name_2="data2_0", alpha=0.1)
r2 = valid.common_random_numbers(data_name_1="data1_1", data_name_2="data2_1", alpha=0.1)
r3 = valid.common_random_numbers(data_name_1="data1_2", data_name_2="data2_2", alpha=0.1)
# Out:
# [INFO] There is already exactly a same analysis in the data.
# [INFO] There is already exactly a same analysis in the data.
# [INFO] There is already exactly a same analysis in the data.
